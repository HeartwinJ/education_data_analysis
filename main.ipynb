# %% [markdown]
# ## Prerequisites

# %%
# %pip install pandas numpy matplotlib tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def print_all_data(df):
	with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.precision', 3):
		display(df)

# %%
df = pd.read_csv('global_education_data.csv')
df.head()
# Out:
#        Country   Latitude  Longitude  OOSR_Pre0Primary_Age_Male  \
# 0  Afghanistan  33.939110  67.709953                          0
# 1      Albania  41.153332  20.168331                          4
# 2      Algeria  28.033886   1.659626                          0
# 3      Andorra  42.506285   1.521801                          0
# 4       Angola  11.202692  17.873887                         31
#
#    OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    OOSR_Primary_Age_Female  OOSR_Lower_Secondary_Age_Male  \
# 0                        0                              0
# 1                        3                              6
# 2                        0                              0
# ...

# %%
print(f"Columns in dataset:\n {df.columns}")
print(f"Shape of dataset:\n {df.shape}")
print(f"Number of rows in dataset:\n {df.shape[0]}")
# Out:
# Columns in dataset:
#  Index(['Country', 'Latitude', 'Longitude', 'OOSR_Pre0Primary_Age_Male',
#        'OOSR_Pre0Primary_Age_Female', 'OOSR_Primary_Age_Male',
#        'OOSR_Primary_Age_Female', 'OOSR_Lower_Secondary_Age_Male',
#        'OOSR_Lower_Secondary_Age_Female', 'OOSR_Upper_Secondary_Age_Male',
#        'OOSR_Upper_Secondary_Age_Female', 'Completion_Rate_Primary_Male',
#        'Completion_Rate_Primary_Female',
#        'Completion_Rate_Lower_Secondary_Male',
#        'Completion_Rate_Lower_Secondary_Female',
#        'Completion_Rate_Upper_Secondary_Male',
#        'Completion_Rate_Upper_Secondary_Female',
#        'Grade_2_3_Proficiency_Reading', 'Grade_2_3_Proficiency_Math',
#        'Primary_End_Proficiency_Reading', 'Primary_End_Proficiency_Math',
#        'Lower_Secondary_End_Proficiency_Reading',
#        'Lower_Secondary_End_Proficiency_Math',
#        'Youth_15_24_Literacy_Rate_Male', 'Youth_15_24_Literacy_Rate_Female',
# ...

# %%
df.drop(columns=['Latitude', 'Longitude', 'Grade_2_3_Proficiency_Reading',
			 'Grade_2_3_Proficiency_Math', 'Primary_End_Proficiency_Reading',
			 'Primary_End_Proficiency_Math', 'Lower_Secondary_End_Proficiency_Reading',
       'Lower_Secondary_End_Proficiency_Math', 'Youth_15_24_Literacy_Rate_Male',
			 'Youth_15_24_Literacy_Rate_Female', 'Birth_Rate', 'Gross_Primary_Education_Enrollment',
       'Gross_Tertiary_Education_Enrollment'], inplace=True)
df.head()
# Out:
#        Country  OOSR_Pre0Primary_Age_Male  OOSR_Pre0Primary_Age_Female  \
# 0  Afghanistan                          0                            0
# 1      Albania                          4                            2
# 2      Algeria                          0                            0
# 3      Andorra                          0                            0
# 4       Angola                         31                           39
#
#    OOSR_Primary_Age_Male  OOSR_Primary_Age_Female  \
# 0                      0                        0
# 1                      6                        3
# 2                      0                        0
# 3                      0                        0
# 4                      0                        0
#
#    OOSR_Lower_Secondary_Age_Male  OOSR_Lower_Secondary_Age_Female  \
# 0                              0                                0
# 1                              6                                1
# ...

# %%
print(f"Columns in dataset:\n {df.columns}")
print(f"Shape of dataset:\n {df.shape}")
print(f"Number of rows in dataset:\n {df.shape[0]}")
# Out:
# Columns in dataset:
#  Index(['Country', 'OOSR_Pre0Primary_Age_Male', 'OOSR_Pre0Primary_Age_Female',
#        'OOSR_Primary_Age_Male', 'OOSR_Primary_Age_Female',
#        'OOSR_Lower_Secondary_Age_Male', 'OOSR_Lower_Secondary_Age_Female',
#        'OOSR_Upper_Secondary_Age_Male', 'OOSR_Upper_Secondary_Age_Female',
#        'Completion_Rate_Primary_Male', 'Completion_Rate_Primary_Female',
#        'Completion_Rate_Lower_Secondary_Male',
#        'Completion_Rate_Lower_Secondary_Female',
#        'Completion_Rate_Upper_Secondary_Male',
#        'Completion_Rate_Upper_Secondary_Female', 'Unemployment_Rate'],
#       dtype='object')
# Shape of dataset:
#  (202, 16)
# Number of rows in dataset:
#  202

# %% [markdown]
# ## Objectives

# %% [markdown]
# ### Aim 1: Analyze out of school rates

# %% [markdown]
# #### 1.1 Top 10 Countries with the highest Out of School Rates

# %%
cols = ['OOSR_Pre0Primary_Age_Male', 'OOSR_Pre0Primary_Age_Female',
				'OOSR_Primary_Age_Male', 'OOSR_Primary_Age_Female',
				'OOSR_Lower_Secondary_Age_Male', 'OOSR_Lower_Secondary_Age_Female',
				'OOSR_Upper_Secondary_Age_Male', 'OOSR_Upper_Secondary_Age_Female']
oosr_aggr = sum([df[col] for col in cols]) / len(cols)

df1_1 = pd.DataFrame({'Country': df['Country'], 'OOSR': oosr_aggr})
df1_1.head()
# Out:
#        Country    OOSR
# 0  Afghanistan  14.125
# 1      Albania   7.250
# 2      Algeria   0.000
# 3      Andorra   0.000
# 4       Angola   8.750

# %%
largest10 = df1_1.nlargest(10, 'OOSR')
print_all_data(largest10)
largest10.plot(x='Country', y='OOSR', ylim=(0, 100), kind='bar', rot=90)
# Out:
#           Country    OOSR
# 129         Niger  67.125
# 167   South Sudan  65.625
# 35           Chad  63.125
# 51       Djibouti  58.625
# 109          Mali  55.875
# 28   Burkina Faso  53.625
# 58        Eritrea  51.375
# 73         Guinea  49.875
# 61       Ethiopia  49.625
# 199         Yemen  49.250
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 1.2 Out of school rates for pre primary education in different countries

# %%
oosr_primary = (df['OOSR_Pre0Primary_Age_Male'] + df['OOSR_Pre0Primary_Age_Female'])/2

df1_2 = pd.DataFrame({'Country': df['Country'], 'OOSR_Pre_Primary': oosr_primary})
df1_2.head()
# Out:
#        Country  OOSR_Pre_Primary
# 0  Afghanistan               0.0
# 1      Albania               3.0
# 2      Algeria               0.0
# 3      Andorra               0.0
# 4       Angola              35.0

# %%
df1_2.plot(x='Country', y='OOSR_Pre_Primary', ylim=(0, 100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 1.3 Out of school rates for primary education in different countries

# %%
oosr_primary = (df['OOSR_Primary_Age_Male'] + df['OOSR_Primary_Age_Female'])/2

df1_3 = pd.DataFrame({'Country': df['Country'], 'OOSR_Primary': oosr_primary})
df1_3.head()
# Out:
#        Country  OOSR_Primary
# 0  Afghanistan           0.0
# 1      Albania           4.5
# 2      Algeria           0.0
# 3      Andorra           0.0
# 4       Angola           0.0

# %%
df1_3.plot(x='Country', y='OOSR_Primary', ylim=(0, 100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 1.4 Out of school rates for lower secondary education in different countries

# %%
oosr_primary = (df['OOSR_Lower_Secondary_Age_Male'] + df['OOSR_Lower_Secondary_Age_Female'])/2

df1_4 = pd.DataFrame({'Country': df['Country'], 'OOSR_Lower_Secondary': oosr_primary})
df1_4.head()
# Out:
#        Country  OOSR_Lower_Secondary
# 0  Afghanistan                   0.0
# 1      Albania                   3.5
# 2      Algeria                   0.0
# 3      Andorra                   0.0
# 4       Angola                   0.0

# %%
df1_4.plot(x='Country', y='OOSR_Lower_Secondary', ylim=(0, 100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 1.5 Out of school rates for upper secondary education in different countries

# %%
oosr_primary = (df['OOSR_Upper_Secondary_Age_Male'] + df['OOSR_Upper_Secondary_Age_Female'])/2

df1_5 = pd.DataFrame({'Country': df['Country'], 'OOSR_Upper_Secondary': oosr_primary})
df1_5.head()
# Out:
#        Country  OOSR_Upper_Secondary
# 0  Afghanistan                  56.5
# 1      Albania                  18.0
# 2      Algeria                   0.0
# 3      Andorra                   0.0
# 4       Angola                   0.0

# %%
df1_5.plot(x='Country', y='OOSR_Upper_Secondary', ylim=(0, 100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ### Aim 2: Examine gender disparities in completion and out of school rates

# %% [markdown]
# #### 2.1 Primary Education

# %% [markdown]
# ##### 2.1.1 Top 10 Countries with the highest Ratio of males to females who are Out of School

# %%
oosr_primary_ratio = df['OOSR_Primary_Age_Male'] / df['OOSR_Primary_Age_Female']

df2_1_1 = pd.DataFrame({'Country': df['Country'], 'OOSR_Primary_Ratio': oosr_primary_ratio})
df2_1_1.replace(np.inf, np.nan, inplace=True)
df2_1_1.dropna(inplace=True)
df2_1_1.head()
# Out:
#                 Country  OOSR_Primary_Ratio
# 1               Albania            2.000000
# 6   Antigua and Barbuda            4.000000
# 8               Armenia            1.000000
# 11           Azerbaijan            1.428571
# 13              Bahrain            0.666667

# %%
largest10 = df2_1_1.nlargest(10, 'OOSR_Primary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='OOSR_Primary_Ratio', kind='bar', rot=90)
# Out:
#                  Country  OOSR_Primary_Ratio
# 6    Antigua and Barbuda               4.000
# 94                Kuwait               4.000
# 81                 India               3.000
# 108             Maldives               3.000
# 113            Mauritius               3.000
# 20                Bhutan               2.500
# 178           East Timor               2.333
# 164      Solomon Islands               2.250
# 1                Albania               2.000
# 70                Greece               2.000
# <Axes: xlabel='Country'>

# %% [markdown]
# ##### 2.1.2 Top 10 Countries with the highest ratio of males to females who complete

# %%
completion_primary_ratio = df['Completion_Rate_Primary_Male'] / df['Completion_Rate_Primary_Female']

df2_1_2 = pd.DataFrame({'Country': df['Country'], 'Completion_Rate_Primary_Ratio': completion_primary_ratio})
df2_1_2.replace(np.inf, np.nan, inplace=True)
df2_1_2.dropna(inplace=True)
df2_1_2.head()
# Out:
#        Country  Completion_Rate_Primary_Ratio
# 0  Afghanistan                       1.675000
# 1      Albania                       0.979167
# 2      Algeria                       1.000000
# 4       Angola                       1.105263
# 7    Argentina                       0.968085

# %%
largest10 = df2_1_2.nlargest(10, 'Completion_Rate_Primary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='Completion_Rate_Primary_Ratio', kind='bar', rot=90)
# Out:
#                       Country  Completion_Rate_Primary_Ratio
# 167               South Sudan                          1.722
# 0                 Afghanistan                          1.675
# 34   Central African Republic                          1.636
# 129                     Niger                          1.458
# 73                     Guinea                          1.333
# 35                       Chad                          1.292
# 199                     Yemen                          1.273
# 109                      Mali                          1.220
# 112                Mauritania                          1.172
# 135                  Pakistan                          1.164
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 2.2 Lower Secondary Education

# %% [markdown]
# ##### 2.2.1 Top 10 Countries with the highest Ratio of males to females who are Out of School

# %%
oosr_lower_secondary_ratio = df['OOSR_Lower_Secondary_Age_Male'] / df['OOSR_Lower_Secondary_Age_Female']

df2_2_1 = pd.DataFrame({'Country': df['Country'], 'OOSR_Lower_Secondary_Ratio': oosr_lower_secondary_ratio})
df2_2_1.replace(np.inf, np.nan, inplace=True)
df2_2_1.dropna(inplace=True)
df2_2_1.head()
# Out:
#                 Country  OOSR_Lower_Secondary_Ratio
# 1               Albania                    6.000000
# 6   Antigua and Barbuda                    0.500000
# 8               Armenia                    1.222222
# 9             Australia                    0.666667
# 12          The Bahamas                    1.095238

# %%
largest10 = df2_2_1.nlargest(10, 'OOSR_Lower_Secondary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='OOSR_Lower_Secondary_Ratio', kind='bar', rot=90)
# Out:
#                             Country  OOSR_Lower_Secondary_Ratio
# 1                           Albania                        6.00
# 125                           Nepal                        4.00
# 170  Palestinian National Authority                        4.00
# 124                           Nauru                        3.25
# 20                           Bhutan                        3.00
# 42                       Costa Rica                        3.00
# 44                          Croatia                        3.00
# 52                         Dominica                        3.00
# 149                          Rwanda                        3.00
# 193                   United States                        3.00
# <Axes: xlabel='Country'>

# %% [markdown]
# ##### 2.2.2 Top 10 Countries with the highest ratio of males to females who complete

# %%
completion_lower_secondary_ratio = df['Completion_Rate_Lower_Secondary_Male'] / df['Completion_Rate_Lower_Secondary_Female']

df2_2_2 = pd.DataFrame({'Country': df['Country'], 'Completion_Rate_Lower_Secondary_Ratio': completion_lower_secondary_ratio})
df2_2_2.replace(np.inf, np.nan, inplace=True)
df2_2_2.dropna(inplace=True)
df2_2_2.head()
# Out:
#        Country  Completion_Rate_Lower_Secondary_Ratio
# 0  Afghanistan                               1.884615
# 1      Albania                               1.010309
# 2      Algeria                               0.753846
# 4       Angola                               1.312500
# 7    Argentina                               0.886076

# %%
largest10 = df2_2_2.nlargest(10, 'Completion_Rate_Lower_Secondary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='Completion_Rate_Lower_Secondary_Ratio', kind='bar', rot=90)
# Out:
#                       Country  Completion_Rate_Lower_Secondary_Ratio
# 129                     Niger                                  2.500
# 167               South Sudan                                  2.200
# 28               Burkina Faso                                  2.167
# 34   Central African Republic                                  2.000
# 19                      Benin                                  1.923
# 0                 Afghanistan                                  1.885
# 35                       Chad                                  1.800
# 73                     Guinea                                  1.650
# 43                Ivory Coast                                  1.636
# 109                      Mali                                  1.440
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 2.3 Upper Secondary Education

# %% [markdown]
# ##### 2.3.1 Top 10 Countries with the highest Ratio of males to females who are Out of School

# %%
oosr_upper_secondary_ratio = df['OOSR_Upper_Secondary_Age_Male'] / df['OOSR_Upper_Secondary_Age_Female']

df2_3_1 = pd.DataFrame({'Country': df['Country'], 'OOSR_Upper_Secondary_Ratio': oosr_upper_secondary_ratio})
df2_3_1.replace(np.inf, np.nan, inplace=True)
df2_3_1.dropna(inplace=True)
df2_3_1.head()
# Out:
#                Country  OOSR_Upper_Secondary_Ratio
# 0          Afghanistan                    0.637681
# 1              Albania                    1.400000
# 6  Antigua and Barbuda                    1.166667
# 7            Argentina                    2.142857
# 8              Armenia                    4.000000

# %%
largest10 = df2_3_1.nlargest(10, 'OOSR_Upper_Secondary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='OOSR_Upper_Secondary_Ratio', kind='bar', rot=90)
# Out:
#                  Country  OOSR_Upper_Secondary_Ratio
# 8                Armenia                       4.000
# 127          New Zealand                       4.000
# 13               Bahrain                       3.000
# 153                Samoa                       3.000
# 15              Barbados                       2.333
# 7              Argentina                       2.143
# 85   Republic of Ireland                       2.000
# 103            Lithuania                       2.000
# 125                Nepal                       2.000
# 159           Seychelles                       2.000
# <Axes: xlabel='Country'>

# %% [markdown]
# ##### 2.3.2 Top 10 Countries with the highest ratio of males to females who complete

# %%
completion_upper_secondary_ratio = df['Completion_Rate_Upper_Secondary_Male'] / df['Completion_Rate_Upper_Secondary_Female']

df2_3_2 = pd.DataFrame({'Country': df['Country'], 'Completion_Rate_Upper_Secondary_Ratio': completion_upper_secondary_ratio})
df2_3_2.replace(np.inf, np.nan, inplace=True)
df2_3_2.dropna(inplace=True)
df2_3_2.head()
# Out:
#        Country  Completion_Rate_Upper_Secondary_Ratio
# 0  Afghanistan                               2.285714
# 1      Albania                               0.950000
# 2      Algeria                               0.594595
# 4       Angola                               1.600000
# 7    Argentina                               0.867925

# %%
largest10 = df2_3_2.nlargest(10, 'Completion_Rate_Upper_Secondary_Ratio')
print_all_data(largest10)
largest10.plot(x='Country', y='Completion_Rate_Upper_Secondary_Ratio', kind='bar', rot=90)
# Out:
#            Country  Completion_Rate_Upper_Secondary_Ratio
# 129          Niger                                  4.000
# 28    Burkina Faso                                  3.000
# 167    South Sudan                                  3.000
# 179           Togo                                  2.583
# 35            Chad                                  2.500
# 19           Benin                                  2.400
# 0      Afghanistan                                  2.286
# 100        Liberia                                  2.000
# 109           Mali                                  1.917
# 74   Guinea0Bissau                                  1.750
# <Axes: xlabel='Country'>

# %% [markdown]
# ### Aim 3: Investigate relationship between education indicators and unemployment rates

# %% [markdown]
# #### 3.1 Top 10 Countries with the highest Unemployment rates

# %%
highest_unemployment = df[['Country', 'Unemployment_Rate']].nlargest(10, 'Unemployment_Rate')
print_all_data(highest_unemployment)
highest_unemployment.plot(x='Country', y='Unemployment_Rate', kind='bar', rot=90)
# Out:
#                               Country  Unemployment_Rate
# 166                      South Africa              28.18
# 99                            Lesotho              23.41
# 151                       Saint Lucia              20.71
# 123                           Namibia              20.27
# 65                              Gabon              20.00
# 152  Saint Vincent and the Grenadines              18.88
# 101                             Libya              18.56
# 22             Bosnia and Herzegovina              18.42
# 23                           Botswana              18.19
# 70                             Greece              17.24
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 3.2 Top 10 Countries with the lowest Unemployment rates

# %%
lowest_unemployment = df[df['Unemployment_Rate'] != 0][['Country', 'Unemployment_Rate']].nsmallest(10, 'Unemployment_Rate')
print_all_data(lowest_unemployment)
lowest_unemployment.plot(x='Country', y='Unemployment_Rate', kind='bar', rot=90)
# Out:
#              Country  Unemployment_Rate
# 144            Qatar               0.09
# 129            Niger               0.47
# 164  Solomon Islands               0.58
# 96              Laos               0.63
# 31          Cambodia               0.68
# 13           Bahrain               0.71
# 177         Thailand               0.75
# 149           Rwanda               1.03
# 181            Tonga               1.12
# 125            Nepal               1.41
# <Axes: xlabel='Country'>

# %% [markdown]
# #### 3.3 Relation between Unemployment and Completion and Out of School Rates

# %% [markdown]
# ##### 3.3.1 Unemployment vs Completion

# %%
unemployment_per_country = df['Unemployment_Rate']
completion_cols = ['Completion_Rate_Primary_Male',
									 'Completion_Rate_Primary_Female',
									 'Completion_Rate_Lower_Secondary_Male',
									 'Completion_Rate_Lower_Secondary_Female',
									 'Completion_Rate_Upper_Secondary_Male',
									 'Completion_Rate_Upper_Secondary_Female']
completion_aggr = sum([df[col] for col in completion_cols]) / len(completion_cols)

df3_3_1 = pd.DataFrame({'Country': df['Country'], 'Unemployment_Rate': unemployment_per_country, 'Completion_Rate': completion_aggr})

df3_3_1.plot(x='Country', y=['Unemployment_Rate', 'Completion_Rate'], ylim=(0,100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ##### 3.3.2 Unemployment vs Out of School Rate

# %%
unemployment_per_country = df['Unemployment_Rate']
oosr_cols = ['OOSR_Pre0Primary_Age_Male',
						 'OOSR_Pre0Primary_Age_Female', 'OOSR_Primary_Age_Male',
						 'OOSR_Primary_Age_Female', 'OOSR_Lower_Secondary_Age_Male',
						 'OOSR_Lower_Secondary_Age_Female', 'OOSR_Upper_Secondary_Age_Male',
						 'OOSR_Upper_Secondary_Age_Female']
oosr_aggr = sum([df[col] for col in oosr_cols]) / len(oosr_cols)

df3_3_1 = pd.DataFrame({'Country': df['Country'], 'Unemployment_Rate': unemployment_per_country, 'OOSR_Rate': oosr_aggr})

df3_3_1.plot(x='Country', y=['Unemployment_Rate', 'OOSR_Rate'], ylim=(0,100), kind='bar', rot=90, figsize=(50, 10))
# Out:
# <Axes: xlabel='Country'>
